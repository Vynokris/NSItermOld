# %%
# Permet de tout executer au lancement du notebook + conserver le notebook actif pendant 2h
from IPython.display import Javascript
from masquer import *
Javascript("""
function repeter(){
IPython.notebook.kernel.execute("a=1");
}
// execute a = 1 en python toutes les 8 minutes pendant 2h
let timerId = setInterval(() => repeter(), 4800);
setTimeout(() => { clearInterval(timerId); alert('fin de cession'); }, 7200000);

// Supprimer la taille limite pour la sortie d'une cellule
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
};
IPython.notebook.kernel.execute("url = '" + window.location + "'");

// Exécuter toutes les cellule du notebook
    require(
        ['base/js/namespace', 'jquery'], 
        function(jupyter, $) {
            
                
                jupyter.actions.call('jupyter-notebook:run-all-cells-below');
                jupyter.actions.call('jupyter-notebook:save-notebook');
                Jupyter.actions.call('jupyter-notebook:hide-header')

        }
    );""")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
HTML("""<style>
h1 {
  font-family: 'Permanent Marker', cursive;
  text-align: center;
  color: red;
  
}
ol {
  list-style-position: inside;
  margin-left: 1em;
  list-style-position: outside;
}
h2 {
  font-family: 'Permanent Marker', cursive;
  color: blue;
}
h3 {
  font-family: 'Permanent Marker', cursive;

}
</style>""")
# Out:
# <style>
# h1 {
#   font-family: 'Permanent Marker', cursive;
#   text-align: center;
#   color: red;
#
# }
# ol {
#   list-style-position: inside;
#   margin-left: 1em;
#   list-style-position: outside;
# }
# h2 {
#   font-family: 'Permanent Marker', cursive;
#   color: blue;
# }
# h3 {
#   font-family: 'Permanent Marker', cursive;
#
# }
# </style>

# %% [markdown]
# # <span style="color:red;"><center>TD_03_1 - Générer des nombres premiers</center></span>

# %% [markdown]
# ## Exercice 1. Crible d'Eratosthène

# %% [markdown]
# On choisit un entier N correspondant à la limite que l’on se fixe.
# On va ensuite aligner tous les entiers (en barrant 0 et 1 avant de commencer) et effectuer le
# processus suivant :
# * Déterminer le plus petit entier n non barré et non encore étudié
# * Barrer tous les multiples de n qui sont strictement supérieurs à n
# * s’il reste des nombres non barrés > n, retourner à la première étape
#
#
# A la fin, tous les nombres non barrés sont des nombres premiers.
# Pour barrer des nombres, on va utiliser un tableau de booléens dont tous les éléments sont
# initialement à True. On passera l’élément à False lorsque l’on veut barrer l’entier correspondant à
# l’indice.
# 1. Ecrire une fonction **initialise_crible(N)** qui prend comme paramètre un entier N et renvoie un tableau de N+1 booléens initialisés à True sauf 0 et 1 initialisés à False.
#
# Par exemple: initialise_crible(10) renvoie [False, False, True, True, True, True, True, True, True, True,True]
#
#
# 2. Ecrire une procédure **barre_multiple(L, n)** qui prend comme paramètres un tableau de booléens L et un entier n. Cette procédure devra barrer tous les multiples stricts de n dans L.
#
#
# 3. Ecrire une fonction **crible(N)** qui prend en entrée un entier N et qui renvoie le tableau de booléens correspondant à l’application de l’algorithme d’Eratosthène pour les entiers positifs inférieurs ou égaux à N.
#
#
# 4. Ecrire une fonction **liste_premier(N)** qui prend en entrée un entier N, utilise les fonctions précédentes et renvoie la liste de tous les nombres premiers inférieurs ou égaux à N.
#
#
# 5. Calculer cette liste pour N le plus grand possible (il faudra estimer la complexité afin de choisir un N de taille raisonnable), stockez la sous forme d'un fichier texte.
#
# 6. Ecrire une fonction **lecture** qui prend en paramètre le chemin d'accès vers le fichier précédent et qui renvoie la liste d'entiers stockés à l'intérieur.

# %%
# question 1.
def initialise_crible(N):
    assert type(N) == int
    L = [True]*(N+1)
    L[0] = False
    L[1] = False
    return temp

L = initialise_crible(10)
print(L)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1c2a44cb118b> in <module>
#       7     return temp
#       8
# ----> 9 L = initialise_crible(10)
#      10 print(L)
#
# <ipython-input-4-1c2a44cb118b> in initialise_crible(N)
#       5     L[0] = False
#       6     L[1] = False
# ----> 7     return temp
#       8
#       9 L = initialise_crible(10)
#
# NameError: name 'temp' is not defined

# %%
# question 2.
def barre_multiple(L, n):
    assert type(L) == list
    assert type(n) == int
    for i in range(n+1, len(L)):
        if i%n == 0:
            L[i] = False
    return L

barre_multiple(L, 2)

# %%
# question 3.
def crible(N):
    assert type(N) == int
    L = initialise_crible(N)
    for i in range(2, len(L)):
        L = barre_multiple(L, i)
    return L

crible(11)

# %%
# question 4.
def liste_premier(N):
    assert type(N) == int
    L = crible(N)
    premier = []
    for i in range(2, len(L)):
        if L[i]:
            premier.append(i)
    return premier

liste_premier(11)

# %%
# question 5.
f = open("premiers.txt", "w")
L = liste_premier(100)
for i in L:
    f.write(str(i))
    f.write(" ")
f.close()

# %%
# question 6.
def lecture(path):
    assert type(path) == str
    f = open(path, "r")
    data = f.readline()
    f.close()
    L = data.split(" ")
    del L[-1]
    L = list(map(int, L)) #Changer de str à int chaque élément de L
    return L

print(lecture("premiers.txt"))

# %% [markdown]
# ## Exercice 2. La fonction puissance

# %% [markdown]
# Nous avons déjà travaillé sur les algorithmes de calcul de puissance. Nous allons travailler ici sur la puissance modulaire.
#
# 1. Ecrire une fonction **puissance_mod** récursive qui prend en argument un float **x**, un entier positif ou nul **n** et un entier **m** et qui renvoie la valeur de $x^n\ mod\ m$ calculée par $x^0 = 1$ et $x^n\ mod\ m = (x\ mod\ m)\times (x^{n-1}\ mod\ m)$
#
# 2. Ecrire une fonction **puissance_mod_rapide** récursive qui prend en argument un float **x**, un entier positif ou nul **n** et un entier **m** et qui renvoie la valeur de $x^n\ mod\ m$ calculée par $x^0 = 1$ et $x^n = (x^{n//2}\ mod\ m) \times (x^{n//2}\ mod\ m)$ si n est pair et $x^n = (x\ mod\ m) \times (x^{n//2}\ mod\ m) \times (x^{n//2}\ mod\ m)$ si n est impair.
#
# 3. Expliquer ce qu'apporte la deuxième fonction par rapport à la première.
#
# 4. Utiliser le module **time** afin d'étudier l'évolution du temps nécessaire pour réaliser ces calculs avec les deux fonctions. Les résultats sont-il en accord avec la complexité de chacune de ces fonctions?

# %%
# Question 1.
def puissance_mod(x, n, m):
    assert type(x) == float or type(x) == int
    assert type(n) == int and n >= 0
    assert type(m) == int
    if n == 0:
        return 1
    else:
        return (x%m)*(puissance_mod(x, n-1, m)%m)

puissance_mod(2, 5, 32)
# Out:
# 32

# %%
# Question 2.
def puissance_mod_rapide(x, n, m):
    assert type(x) == float or type(x) == int
    assert type(n) == int and n >= 0
    assert type(m) == int
    if n == 0:
        return 1
    else:
        temp = puissance_mod_rapide(x, n//2, m)
        if n%2 == 0:
            return (temp%m)*(temp%m)
        else:
            return (x%m)*(temp%m)*(temp%m)

puissance_mod_rapide(2, 5, 32)
# Out:
# 32

# %% [markdown]
# ***Question 3 :*** La 2e fonction est plus rapide que la 1ère car elle s'appelle beaucoup moins de fois.

# %%
# Question 4.
from time import time
t = time()
puissance_mod(100, 1000, 32)
print(time()-t)
t = time()
puissance_mod_rapide(100, 1000, 32)
print(time()-t)
# Out:
# 0
# 0.003953218460083008
# 0
# 0.002681255340576172

# %% [markdown]
# ***Question 4 :*** Souvent, la deuxième fonction est plus rapide, même si les deux sont assez proches en termes de durée.
